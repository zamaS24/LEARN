# %% [markdown]
# # Grouping and sorting

# %%
import pandas as pd
pd.set_option("display.max_rows", 5)

reviews = pd.read_csv("datasets/winemag-data-130k-v2.csv", index_col=0)

reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
# we used to do reviews.points.value_counts()
# it's like doing this : 
reviews.groupby('points').designation.count()
# Out:
# points
# 80     250
# 81     406
#       ...
# 99      29
# 100     13
# Name: designation, Length: 21, dtype: int64

# %% [markdown]
# You can think of each group we generate as being a slice of our DataFrame containing only data with values that match. This DataFrame is accessible to us directly using the apply() method, and we can then manipulate the data in any way we see fit. For example, here's one way of selecting the name of the first wine reviewed from each winery in the dataset:
#
# meaning that for each element in the groupby what do you want to append to it? it could be an entire row, or an entire dataframe, or just a value, you can do whatever you want in the datafram

# %%
x = reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# x here is a series, 
x
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
x = reviews.groupby('winery').apply(lambda df: df.iloc[0:2])

# x.iloc[0]
# x is a data frame
print('Type of x : ', type(x))
x
# Out:
# Type of x :  <class 'pandas.core.frame.DataFrame'>
#                country                                        description  \
# winery
# 1+1=3  20319     Spain  A dusty, yeasty nose is simplistic but friendl...
#        33657     Spain  Clean, fresh apple aromas and a minerally, cit...
# ...                ...                                                ...
# Štoka  10290  Slovenia  Vanilla and cookie crumb notes add a sweet, to...
#        70504  Slovenia  This orange-style wine is dark straw in color ...
#
#                                                     designation  points  \
# winery
# 1+1=3  20319                                               Rosé      86
#        33657  Cygnus Brut Nature Reserva Made With Organic G...      89
# ...                                                         ...     ...
# Štoka  10290                                            Izbrani      88
#        70504                                            Grganja      90
#
# ...

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
# ...

# %% [markdown]
# ### agg() with multipple agg functions

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %% [markdown]
# ### Multi-indexes

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
# Out:
# RangeIndex(start=0, stop=425, step=1)

# %% [markdown]
# ### reseting the index

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# # Sorting

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#     country               province    len
# 179  Greece  Muscat of Kefallonian      1
# 192  Greece          Sterea Ellada      1
# ..      ...                    ...    ...
# 415      US             Washington   8639
# 392      US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#     country    province    len
# 392      US  California  36247
# 415      US  Washington   8639
# ..      ...         ...    ...
# 63    Chile     Coelemu      1
# 149  Greece      Beotia      1
#
# [425 rows x 3 columns]

# %% [markdown]
# # Sorting by more than one column

# %%
x= countries_reviewed.sort_values(by=['country', 'len'], ascending=True).country
x
# Out:
# 1      Argentina
# 0      Argentina
#          ...
# 424      Uruguay
# 419      Uruguay
# Name: country, Length: 425, dtype: object

# %%
country_variety_counts = reviews.groupby(['country', 'variety']).description.count().sort_values(ascending=False)

country_variety_counts
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Name: description, Length: 1612, dtype: int64
