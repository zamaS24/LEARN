# %%
"""
torchvision 
"""

import torch 
import torchvision 
from wine_dataset import WineDataset

# %%
dataset = torchvision.datasets.MNIST(
    root='./', 
    transform=torchvision.transforms.ToTensor(), 
    download=True
)

# %%
img_tensor, label = dataset[0]

images = [ [sample[0], [sample[1]]] for sample in dataset]

# %%
import numpy as np
